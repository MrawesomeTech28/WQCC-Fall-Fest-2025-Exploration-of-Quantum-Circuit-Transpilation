# %%
### Installing required packages and importing packages.

# %pip install qiskit[visualization]
# %pip install qiskit_aer
# %pip install qiskit_ibm_runtime

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import SamplerV2 as Sampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.visualization import plot_histogram
# Out:
# Running cells with '.venv (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/TechG/OneDrive - UW-Madison/Documents/GitHub/WQCC-Fall-Fest-2025-Exploration-of-Quantum-Circuit-Transpilation/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
